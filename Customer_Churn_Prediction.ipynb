# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Telco_customer_churn (1).xlsx")

# %% [markdown]
# # New Section

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'], bins=30, kde=True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('Distribution of Tenure Months vs no of customer')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label', y='Tenure Months' , data=df)
plt.xlabel('churn label')
plt.ylabel('tenure month')
plt.title('churn vs tenure motn')
plt.show()

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df [df['Churn Label']=='Yes']
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 1864  1699-HPSBG      1  United States  California  Palm Springs     92264
# 1865  8775-CEBBJ      1  United States  California        Seeley     92273
# 1866  6894-LFHLY      1  United States  California         Vidal     92280
# 1867  0639-TSIQW      1  United States  California   White Water     92282
# 1868  8361-LTMKD      1  United States  California  Apple Valley     92307
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1      34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2     34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3     34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4     34.039224, -118.266293  34.039224 -118.266293    Male  ...
# ...                      ...        ...         ...     ...  ...
# 1864  33.745746, -116.514215  33.745746 -116.514215    Male  ...
# 1865  32.790282, -115.689559  32.790282 -115.689559  Female  ...
# 1866  34.264124, -114.717964  34.264124 -114.717964    Male  ...
# 1867  33.972293, -116.654195  33.972293 -116.654195  Female  ...
# 1868   34.55082, -117.122396  34.550820 -117.122396    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes               Mailed check
# 1     Month-to-month               Yes           Electronic check
# 2     Month-to-month               Yes           Electronic check
# 3     Month-to-month               Yes           Electronic check
# 4     Month-to-month               Yes  Bank transfer (automatic)
# ...              ...               ...                        ...
# 1864        One year               Yes           Electronic check
# 1865  Month-to-month               Yes  Bank transfer (automatic)
# 1866  Month-to-month               Yes           Electronic check
# 1867  Month-to-month               Yes    Credit card (automatic)
# 1868  Month-to-month               Yes               Mailed check
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0               53.85        108.15         Yes           1          86  3239
# 1               70.70        151.65         Yes           1          67  2701
# 2               99.65         820.5         Yes           1          86  5372
# 3              104.80       3046.05         Yes           1          84  5003
# 4              103.70        5036.3         Yes           1          89  5340
# ...               ...           ...         ...         ...         ...   ...
# 1864            59.80         727.8         Yes           1          69  4581
# 1865            44.20        403.35         Yes           1          87  2029
# 1866            75.75         75.75         Yes           1          97  5571
# 1867           102.95       6886.25         Yes           1          70  5620
# 1868            74.40         306.6         Yes           1          77  5839
#
#                                    Churn Reason
# 0                  Competitor made better offer
# 1                                         Moved
# 2                                         Moved
# 3                                         Moved
# 4                 Competitor had better devices
# ...                                         ...
# 1864  Competitor offered higher download speeds
# 1865  Competitor offered higher download speeds
# 1866  Competitor offered higher download speeds
# 1867               Competitor offered more data
# 1868               Competitor offered more data
#
# [1869 rows x 33 columns]

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'], bins=30, kde=True)
plt.xlabel('months charges')
plt.ylabel('Customer count')
plt.title('Distribution of months charges vs no of customer')
plt.show()

# %%
df['Monthly Charges'].max()
# Out:
# 118.75

# %%
df['Monthly Charges'].min()
# Out:
# 18.25

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label', y='Monthly Charges' , data=df)
plt.xlabel('churn label')
plt.ylabel('month charges')
plt.title('churn vs month charges')
plt.show()

# %%
df [df['Churn Label']=='Yes'] ['Monthly Charges'].quantile ([0.25,0.5,0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    35.50
# 0.50    70.35
# 0.75    89.85
# Name: Monthly Charges, dtype: float64

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Internet Service', hue='Churn Label', data=df)
plt.xlabel('Internet Service')
plt.ylabel('count')
plt.title('Internet Service vs count')
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Payment Method', hue='Churn Label', data=df)
plt.xlabel('Payment Method')
plt.ylabel('count')
plt.title('Payment Method  vs count')
plt.show()

# %%
avg_tenure=df.groupby("Churn Label")['Tenure Months'].mean()

# %%
avg_tenure=df.groupby("Churn Label")['Tenure Months'].mean()

# %%
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
numerical_cols = ['Tenure Months', 'Monthly Charges', 'Churn Value', 'Churn Score', 'CLTV']
correlation_matrix = df[numerical_cols].corr()

# %%
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value  Churn Score  \
# Tenure Months         1.000000         0.247900    -0.352229    -0.224987
# Monthly Charges       0.247900         1.000000     0.193356     0.133754
# Churn Value          -0.352229         0.193356     1.000000     0.664897
# Churn Score          -0.224987         0.133754     0.664897     1.000000
# CLTV                  0.396406         0.098693    -0.127463    -0.079782
#
#                      CLTV
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
contract_churn = pd.crosstab(df['Contract'], df['Churn Label'], normalize='index')

# %%
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %% [markdown]
# Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df[['Total Charges', 'Tenure Months']].isnull().sum()
# Out:
# Total Charges    11
# Tenure Months     0
# dtype: int64

# %%
# Show specific columns where 'Total Charges' is missing
df.loc[df['Total Charges'].isnull(), ['Total Charges', 'Tenure Months']]
# Out:
#       Total Charges  Tenure Months
# 2234            NaN              0
# 2438            NaN              0
# 2568            NaN              0
# 2667            NaN              0
# 2856            NaN              0
# 4331            NaN              0
# 4687            NaN              0
# 5104            NaN              0
# 5719            NaN              0
# 6772            NaN              0
# 6840            NaN              0

# %%
df[df['Total Charges'].isnull()][['Tenure Months']]
#Returns a DataFrame showing the 'Tenure Months' values for all rows where 'Total Charges' is missing
# Out:
#       Tenure Months
# 2234              0
# 2438              0
# 2568              0
# 2667              0
# 2856              0
# 4331              0
# 4687              0
# 5104              0
# 5719              0
# 6772              0
# 6840              0

# %%
# 2. Corrected drop (without StateID)
drop_columns = ['CustomerID', 'Count', 'Country', 'State', 'Zip Code']
df = df.drop(columns=drop_columns)

# %%
# 3. Check shape after dropping
df.shape
# Out:
# (7043, 28)

# %% [markdown]
# City Encoding

# %%
df['City'].unique()

df['City'].value_counts()
# Out:
# City
# Los Angeles      305
# San Diego        150
# San Jose         112
# Sacramento       108
# San Francisco    104
#                 ...
# Chester            4
# Big Bar            4
# Washington         4
# Stonyford          4
# Stirling City      4
# Name: count, Length: 1129, dtype: int64

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df = df.drop(columns=['City'])

# %%
# 4. Get dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7043 non-null   object
#  1   Lat Long           7043 non-null   object
#  2   Latitude           7043 non-null   float64
#  3   Longitude          7043 non-null   float64
#  4   Gender             7043 non-null   object
#  5   Senior Citizen     7043 non-null   object
#  6   Partner            7043 non-null   object
#  7   Dependents         7043 non-null   object
#  8   Tenure Months      7043 non-null   int64
#  9   Phone Service      7043 non-null   object
#  10  Multiple Lines     7043 non-null   object
#  11  Internet Service   7043 non-null   object
#  12  Online Security    7043 non-null   object
#  13  Online Backup      7043 non-null   object
#  14  Device Protection  7043 non-null   object
#  15  Tech Support       7043 non-null   object
#  16  Streaming TV       7043 non-null   object
#  17  Streaming Movies   7043 non-null   object
#  18  Contract           7043 non-null   object
#  19  Paperless Billing  7043 non-null   object
#  20  Payment Method     7043 non-null   object
#  21  Monthly Charges    7043 non-null   float64
#  22  Total Charges      7032 non-null   float64
#  23  Churn Label        7043 non-null   object
#  24  Churn Value        7043 non-null   int64
#  25  Churn Score        7043 non-null   int64
#  26  CLTV               7043 non-null   int64
#  27  Churn Reason       1869 non-null   object
# dtypes: float64(4), int64(4), object(20)
# memory usage: 1.5+ MB

# %% [markdown]
# Feature / Target Split

# %%
# 5. Create dummy variables for categorical columns
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
# 6. View first few rows of encoded dataframe
df_encoded.head()
# Out:
#     Latitude   Longitude  Tenure Months  Monthly Charges  Total Charges  \
# 0  33.964131 -118.272783              2            53.85         108.15
# 1  34.059281 -118.307420              2            70.70         151.65
# 2  34.048013 -118.293953              8            99.65         820.50
# 3  34.062125 -118.315709             28           104.80        3046.05
# 4  34.039224 -118.266293             49           103.70        5036.30
#
#    Churn Value  Churn Score  CLTV  City_Acton  City_Adelanto  ...  \
# 0            1           86  3239       False          False  ...
# 1            1           67  2701       False          False  ...
# 2            1           86  5372       False          False  ...
# 3            1           84  5003       False          False  ...
# 4            1           89  5340       False          False  ...
#
#    Churn Reason_Lack of self-service on Website  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Churn Reason_Limited range of services  Churn Reason_Long distance charges  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#    Churn Reason_Moved  Churn Reason_Network reliability  \
# 0               False                             False
# 1                True                             False
# 2                True                             False
# 3                True                             False
# 4               False                             False
#
#    Churn Reason_Poor expertise of online support  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Churn Reason_Poor expertise of phone support  Churn Reason_Price too high  \
# 0                                         False                        False
# 1                                         False                        False
# 2                                         False                        False
# 3                                         False                        False
# 4                                         False                        False
#
#    Churn Reason_Product dissatisfaction  Churn Reason_Service dissatisfaction
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
# [5 rows x 2834 columns]

# %%
# 8. Check shape after dropping City
df.shape
# Out:
# (7043, 28)

# %%
# 9. Check missing values in Total Charges
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
# 10. Check data type of Total Charges
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
# 11. Define features (X) and target (y)
x = df_encoded.drop('Churn Value', axis=1)
y = df_encoded['Churn Value']

# %%
# 12. Check shapes
x.shape
y.shape
# Out:
# (7043,)

# %%
# 13. Print features
print(x)
# Out:
#        Latitude   Longitude  Tenure Months  Monthly Charges  Total Charges  \
# 0     33.964131 -118.272783              2            53.85         108.15
# 1     34.059281 -118.307420              2            70.70         151.65
# 2     34.048013 -118.293953              8            99.65         820.50
# 3     34.062125 -118.315709             28           104.80        3046.05
# 4     34.039224 -118.266293             49           103.70        5036.30
# ...         ...         ...            ...              ...            ...
# 7038  34.341737 -116.539416             72            21.15        1419.40
# 7039  34.667815 -117.536183             24            84.80        1990.50
# 7040  34.559882 -115.637164             72           103.20        7362.90
# 7041  34.167800 -116.864330             11            29.60         346.45
# 7042  34.424926 -117.184503             66           105.65        6844.50
#
#       Churn Score  CLTV  City_Acton  City_Adelanto  City_Adin  ...  \
# 0              86  3239       False          False      False  ...
# 1              67  2701       False          False      False  ...
# 2              86  5372       False          False      False  ...
# 3              84  5003       False          False      False  ...
# 4              89  5340       False          False      False  ...
# ...           ...   ...         ...            ...        ...  ...
# 7038           45  5306       False          False      False  ...
# 7039           59  2140       False           True      False  ...
# 7040           71  5560       False          False      False  ...
# 7041           59  2793       False          False      False  ...
# 7042           38  5097       False          False      False  ...
#
#       Churn Reason_Lack of self-service on Website  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 7038                                         False
# 7039                                         False
# 7040                                         False
# 7041                                         False
# 7042                                         False
#
#       Churn Reason_Limited range of services  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 7038                                   False
# 7039                                   False
# 7040                                   False
# 7041                                   False
# 7042                                   False
#
#       Churn Reason_Long distance charges  Churn Reason_Moved  \
# 0                                  False               False
# 1                                  False                True
# 2                                  False                True
# 3                                  False                True
# 4                                  False               False
# ...                                  ...                 ...
# 7038                               False               False
# 7039                               False               False
# 7040                               False               False
# 7041                               False               False
# 7042                               False               False
#
#       Churn Reason_Network reliability  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 7038                             False
# 7039                             False
# 7040                             False
# 7041                             False
# 7042                             False
#
#       Churn Reason_Poor expertise of online support  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 7038                                          False
# 7039                                          False
# 7040                                          False
# 7041                                          False
# 7042                                          False
#
#       Churn Reason_Poor expertise of phone support  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 7038                                         False
# 7039                                         False
# 7040                                         False
# 7041                                         False
# 7042                                         False
#
#       Churn Reason_Price too high  Churn Reason_Product dissatisfaction  \
# 0                           False                                 False
# 1                           False                                 False
# 2                           False                                 False
# 3                           False                                 False
# 4                           False                                 False
# ...                           ...                                   ...
# 7038                        False                                 False
# 7039                        False                                 False
# 7040                        False                                 False
# 7041                        False                                 False
# 7042                        False                                 False
#
#       Churn Reason_Service dissatisfaction
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 7038                                 False
# 7039                                 False
# 7040                                 False
# 7041                                 False
# 7042                                 False
#
# [7043 rows x 2833 columns]

# %%
# 14. Print target
print(y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %% [markdown]
# Train Test Split

# %%
# 15. Import train_test_split
from sklearn.model_selection import train_test_split

# %%
# 16. Split the data (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# 17. Check shapes of splits
X_train.shape
# (5634, 30)
X_test.shape
# (1409, 30)
y_train.shape
# (5634,)
y_test.shape
# (1409,)
# Out:
# (1409,)

# %% [markdown]
# Random Forest

# %%
# 18. Import Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# %%
# 19. Create Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# 20. Train the model
rf_model.fit(X_train, y_train)
# Output: RandomForestClassifier(random_state=42)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# 21. Make predictions
y_pred = rf_model.predict(X_test)

# %% [markdown]
# Class Imbalance Handling

# %%
rf_balanced = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    class_weight='balanced'
)

# %%
# 22. View actual test values
y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
# 23. View predictions
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
print(x.shape)
print(y.shape)
# Out:
# (7043, 2833)
# (7043,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (5634, 2833)
# (5634,)

# %% [markdown]
# Approach 2 :Hyperparameter Tuning

# %%
rf_tuned = RandomForestClassifier(
    n_estimators=350,
    max_depth=11,
    random_state=42,
    class_weight='balanced'
)


rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=350,
#                        random_state=42)

# %%
feature_importances = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf_tuned.feature_importances_
})

feature_importances = feature_importances.sort_values(
    by='Importance',
    ascending=False
)

print(feature_importances.head(20))
# Out:
#                                                 Feature  Importance
# 2813                                    Churn Label_Yes    0.213242
# 5                                           Churn Score    0.135473
# 2                                         Tenure Months    0.047639
# 2808                                  Contract_Two year    0.041495
# 4                                         Total Charges    0.038958
# 2793                       Internet Service_Fiber optic    0.036541
# 2794                                Internet Service_No    0.022732
# 2817  Churn Reason_Competitor offered higher downloa...    0.021541
# 2811                    Payment Method_Electronic check    0.021531
# 2789                                     Dependents_Yes    0.021000
# 2803                   Streaming TV_No internet service    0.019669
# 2795                Online Security_No internet service    0.019645
# 2814            Churn Reason_Attitude of support person    0.019232
# 3                                       Monthly Charges    0.018133
# 2799              Device Protection_No internet service    0.017659
# 2805               Streaming Movies_No internet service    0.017498
# 2796                                Online Security_Yes    0.015751
# 2820                            Churn Reason_Don't know    0.014748
# 2807                                  Contract_One year    0.014734
# 2801                   Tech Support_No internet service    0.014650

# %%
print(rf_tuned)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=350,
#                        random_state=42)

# %%
rf_tuned.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=350,
#                        random_state=42)

# %%
y_pred_tuned = rf_tuned.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1009
#            1       0.93      0.98      0.95       400
#
#     accuracy                           0.97      1409
#    macro avg       0.96      0.97      0.97      1409
# weighted avg       0.97      0.97      0.97      1409

# %% [markdown]
# Accuracy

# %%
# 24. Import accuracy_score
from sklearn.metrics import accuracy_score

# %%
# 25. Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# %%
# 26. Print accuracy
print(accuracy)
# 0.7856635911994322 (approximately 78.57%)
# Out:
# 0.9992902767920511

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1009    0]
#  [   1  399]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1009
#            1       1.00      1.00      1.00       400
#
#     accuracy                           1.00      1409
#    macro avg       1.00      1.00      1.00      1409
# weighted avg       1.00      1.00      1.00      1409

# %% [markdown]
# Feature Importance

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

print(feature_importance.head(10))
# Out:
#                                                 Feature  Importance
# 2813                                    Churn Label_Yes    0.287753
# 5                                           Churn Score    0.152896
# 2                                         Tenure Months    0.035137
# 4                                         Total Charges    0.029127
# 2817  Churn Reason_Competitor offered higher downloa...    0.022170
# 2814            Churn Reason_Attitude of support person    0.020707
# 2820                            Churn Reason_Don't know    0.019355
# 2818          Churn Reason_Competitor offered more data    0.016253
# 3                                       Monthly Charges    0.016066
# 2816          Churn Reason_Competitor made better offer    0.014475

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score

cv_accuracy = cross_val_score(
    rf_tuned,
    x,
    y,
    cv=5,
    scoring='accuracy'
)

print(cv_accuracy)
print("Mean Accuracy:", cv_accuracy.mean())
# Out:
# [0.97941803 0.98012775 0.98367637 0.96377841 0.96519886]
# Mean Accuracy: 0.9744398832182721

# %%
import matplotlib.pyplot as plt

top10 = feature_importance.head(10)

plt.figure(figsize=(8,5))
plt.barh(top10['Feature'], top10['Importance'])
plt.xlabel("Importance")
plt.ylabel("Features")
plt.title("Top 10 Important Features")
plt.show()

# %%
import joblib

joblib.dump(rf_model, "churn_model.pkl")
# Out:
# ['churn_model.pkl']

# %% [markdown]
# ## Customer Churn Prediction using Random Forest
#
# This project aims to predict customer churn using machine learning techniques. Customer churn prediction helps organizations identify customers who are likely to leave the service so that retention strategies can be applied.

# %%
model = joblib.load("churn_model.pkl")

# %%
from google.colab import files
files.download("churn_model.pkl")

# %%
y_prob1 = model.predict_proba(X_test)
churn_prob = y_prob1[:,1]

# %% [markdown]
# ## Model Evaluation
#
# The performance of the Random Forest model is evaluated using the ROC-AUC score. A higher ROC-AUC score indicates better ability to distinguish between churned and non-churned customers.

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, churn_prob)

auc_score = roc_auc_score(y_test, churn_prob)

print("ROC-AUC Score:", auc_score)
# Out:
# ROC-AUC Score: 1.0
